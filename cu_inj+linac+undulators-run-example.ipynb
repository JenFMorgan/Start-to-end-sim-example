# %% [markdown]
# # cu_inj Reference simulation

# %%
# %pylab --no-import-all inline
# %config InlineBackend.figure_format = 'retina'

# %%
from impact import Impact
from distgen import Generator
import os
from pmd_beamphysics.plot import density_and_slice_plot, slice_plot
NAME = 'impact_cu_inj_v0_300k_particles'
import matplotlib.pyplot as plt
#GFILE = os.path.expandvars('$LCLS_LATTICE/distgen/models/cu_inj/vcc_image/distgen.yaml')
GFILE = os.path.expandvars('$LCLS_LATTICE/distgen/models/cu_inj/v0/distgen.yaml')
# YFILE = os.path.expandvars('$LCLS_LATTICE/impact/models/cu_inj/v0/ImpactT.yaml')
infile = os.path.expandvars('$LCLS_LATTICE/impact/models/cu_inj/v0/ImpactT.in')
IFILE = os.path.expandvars(infile)

# %%
# %%time
G = Generator(GFILE)
G['n_particle'] = 300_000
G.run()
P0 = G.particles
# Out:
# CPU times: user 2.98 s, sys: 23.9 ms, total: 3 s
# Wall time: 3.01 s

# %% [markdown]
# # MPI run 300k particles
#
# For this many particles we will prepare an MPI run

# %%
# I = Impact.from_yaml(YFILE)
I = Impact(IFILE, workdir=os.path.expandvars('$SCRATCH'))
# Set initial particles
I.initial_particles = P0
I.workdir=os.path.expandvars('$SCRATCH')
## Switches for MPI
I.numprocs = 60
I.stop = 16.5
I.mpi_run
# Out:
# 'mpirun -n {nproc} {command_mpi}'

# %%
# Change some things
I.header['Nx'] = 64
I.header['Ny'] = 64
I.header['Nz'] = 64

# %% [markdown]
# # Run on S3DF
#
# This will run on SLAC's S3DF. Note that you must have access to a partition (allocation) for instant response.

# %%
 # SDF setup    
settings = { 
 'command': '/sdf/group/ad/beamphysics/software/impact-T/single_processor/ImpactTexe',    
 'command_mpi': '/sdf/group/ad/beamphysics/software/impact-T/openmpi/ImpactTexe-mpi',
 'mpi_run': 'salloc --partition milano --account ad:beamphysics -N 1 -n {nproc} /usr/lib64/openmpi/bin/mpirun -n {nproc} {command_mpi}'
}
for k, v in settings.items():
    I[k] = v
    
I.workdir = os.path.expandvars('$SCRATCH')
I.configure()
print(I)
# Out:
# ================ Impact-T Summary ================
# 300000 particles
# 1 bunch of electrons
# total charge: 250.0000000000001 pC
# Distribution type: read
# Cathode start at z = 0 m
#    emission time: 6.515803466731775e-12 s
#    image charges neglected after z = 0.02 m
# Processor domain: 4 x 15 = 60 CPUs
# Space charge grid: 64 x 64 x 64
# Maximum time steps: 1000000
# Reference Frequency: 2856000000.0 Hz
# Initial reference time: -3.249141278122655e-12 s
# Simulation starting from the beginning
# =================================================
# Impact-T configured in /sdf/scratch/users/j/jmorgan/tmpxjvaxhal

# %%
# %%time
I.verbose=True
I.run()
# Out:
# Running Impact-T in /sdf/scratch/users/j/jmorgan/tmpxjvaxhal
# salloc --partition milano --account ad:beamphysics -N 1 -n 60 /usr/lib64/openmpi/bin/mpirun -n 60 /sdf/group/ad/beamphysics/software/impact-T/openmpi/ImpactTexe-mpi
# writing 300000 particles to /sdf/scratch/users/j/jmorgan/tmpxjvaxhal/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 300000 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 6.502797870989826e-12 according to initial particles
# Cathode start: Replaced Tini with -3.260159390738143e-12 according to initial particles
# Setting total charge to 2.500000000000001e-10 C
# salloc: Pending job allocation 44735962
# salloc: job 44735962 queued and waiting for resources
# salloc: job 44735962 has been allocated resources
# salloc: Granted job allocation 44735962
# salloc: Waiting for resource configuration
# salloc: Nodes sdfmilan004 are ready for job
#  !-----------------------------------------------------------
#  ! IMPACT-T Parallel Beam Dynamics Tracking Code: V2.2
#  ! Copyright of The Regents of the University of California
#  !-----------------------------------------------------------
#  nblem:           32          32
#  pass setting up lattice...
#  check randomness:           59  0.78710099994577631
#  check randomness:           15  0.79204185913161529
#  check randomness:           17  0.95564768400121902
#  check randomness:           18  0.43521250170536463
#  check randomness:           19  0.85358990969505566
#  check randomness:           20  0.62406149781818587
#  check randomness:           21   1.5074646496361477E-002
#  check randomness:           22  0.63285359607562963
#  time:    568.07298787299999, elapsed: 607.43564891815194985421222857, elapsed: 605.9397127628326715975
# salloc: Relinquishing job allocation 44735962
# salloc: Job allocation 44735962 has been revoked.
# Finished.
# Loaded fort 26 : RMS Z information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 24 : RMS X information
# Loaded fort 27 : Max amplitude information
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 18 : Time and energy
# Loaded fort 25 : RMS Y information
# Loaded fort 60 : Slice information of the initial distribution
# Loaded fort 70 : Slice information of the final distribution
# Loading particles
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded write beam particles YAG02 fort.102
# Loaded write beam particles YAG03 fort.103
# Loaded write beam particles WS01 fort.104
# Loaded write beam particles OTR1 fort.105
# Loaded write beam particles WS02 fort.106
# Loaded write beam particles OTR2 fort.107
# Loaded write beam particles WS03 fort.108
# Loaded write beam particles OTR3 fort.109
# Converted final_particles to ParticleGroup
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted YAG02 to ParticleGroup
# Converted YAG03 to ParticleGroup
# Converted WS01 to ParticleGroup
# Converted OTR1 to ParticleGroup
# Converted WS02 to ParticleGroup
# Converted OTR2 to ParticleGroup
# Converted WS03 to ParticleGroup
# Converted OTR3 to ParticleGroup
# CPU times: user 9.39 s, sys: 2.64 s, total: 12 s
# Wall time: 10min 13s

# %%
I.plot('norm_emit_x', y2='mean_kinetic_energy', ylim=(0, 2e-6), figsize=(16,12), include_labels=False)

# %%
I.plot(['sigma_x', 'sigma_y', 'sigma_z'], y2='mean_kinetic_energy',  ylim=(0, 0.001), xlim=(0, 16.5), figsize=(16, 12), include_labels=True)

# %%
I.particles.keys()
# Out:
# dict_keys(['final_particles', 'initial_particles', 'YAG02', 'YAG03', 'WS01', 'OTR1', 'WS02', 'OTR2', 'WS03', 'OTR3'])

# %%
P1 = I.particles['YAG03']

P1.plot('delta_z', 'x')

# %%
P1.plot('delta_z', 'pz')

# %%
P1.plot('x', 'px')

# %%
# 95% Twiss and Emittance
P1.twiss('xy', 0.95)
# Out:
# {'alpha_x': 0.13842967331583744,
#  'beta_x': 4.081839836817056,
#  'gamma_x': 0.24968220586750262,
#  'emit_x': 1.3550159413191163e-09,
#  'eta_x': -6.4429642489628925e-06,
#  'etap_x': 1.6108262323141144e-05,
#  'norm_emit_x': 3.5468362115954787e-07,
#  'alpha_y': 1.0563420822831227,
#  'beta_y': 1.6571290150278943,
#  'gamma_y': 1.2768218862950915,
#  'emit_y': 1.3277600987361381e-09,
#  'eta_y': 2.3735010982422202e-05,
#  'etap_y': 1.5081067946649705e-06,
#  'norm_emit_y': 3.4754913165586797e-07}

# %%
PFILE0 = './linac/impact_inj_output.h5'
I.particles['YAG03'].write(PFILE0)

# %% [markdown]
# # Inject IMPACT output into Tao/PyTao

# %%
from pytao import Tao
from pmd_beamphysics import ParticleGroup

# %% [markdown]
# ## Parameters

# %%
TRACK_START ="YAG03" # Where to start particle tracking (injection element)
TRACK_END = "ENDCLTH_0"#"WSDL31" #"HXRCB1END" #"BC1CEND" # Where to end particle tracking
# Get particles from Lume-Impact sc_inj model, e.g.: 
# I.particles['final_particles'].write('impact_particles_at_14m.h5')

#PFILE0 =  '/sdf/home/j/jmorgan/lclsrepo_dontsharethese/lcls-lattice/bmad/beams/YAG03_100k.h5'
PFILE0 = './linac/impact_inj_output.h5'
# File to write
PFILE = f'bmad_particles_at_{TRACK_START}.h5' 

# Twiss Match parameters (optional) 
twiss_match = True

# %% [markdown]
# ## Initialize Tao and get reference time

# %% [markdown]
# ### Running BMAD Simulations with Graphical Output on S3DF Jupyter Notebook
#
# To run BMAD simulations with graphical output on S3DF Jupyter Notebook, follow these steps:
#
# 1. **Find the Hostname:**
#    - Run the command `hostname` to find out the hostname of the machine where the Jupyter is running.
# 2. **Establish SSH Connection with X11 Forwarding:**
#    - From your local machine, use SSH with X11 forwarding enabled:
#      ```bash
#      ssh -Y <your-username>@<remote-hostname>
#      ```
#      For example:
#      ```bash
#      ssh -Y zihanzhu@s3dflogin
#      ```
#    - Then, SSH to the specific iana node:
#      ```bash
#      ssh -Y zihanzhu@sdfiana008
#      ```
#    - Retrieve the DISPLAY variable using:
#      ```bash
#      echo $DISPLAY
#      ```
# 3. **Set DISPLAY Environment Variable in Notebook:**
#    - Back to Jupyter, set the DISPLAY environment variable in the notebook:
#      ```bash
#      %env DISPLAY=<DISPLAY variable>
#      ```
# Now, the graphical interface should appear when you run BMAD with Tao/PyTao. Special thanks to Michael Enrlichman for guidance.

# %%
#%env DISPLAY=:44.0  #may need to uncomment this

# %%
tao = Tao('-lat $LCLS_LATTICE/bmad/models/cu_hxr/cu_hxr.lat.bmad')

# %%
tao = Tao(f'-init $LCLS_LATTICE/bmad/models/cu_hxr/tao.init -slice BEGINNING:{TRACK_END}')
#tao = Tao(f'-init $LCLS_LATTICE/bmad/models/cu_hxr/tao.init -slice {TRACK_START}:{TRACK_END}')
tao.cmd('place floor sigmaxy')
# Out:
# []

# %%
t_ref = tao.evaluate(f'ele::{TRACK_START}[ref_time]')[0]

t_ref
# Out:
# 1.5413714264595368e-08

# %% [markdown]
# # Prepare particles

# %%
P = ParticleGroup(PFILE0)

# Change to s-coordinates (different times t, constant z)
P.drift_to_z() # drift to P['mean_z']

# Zero out the mean time
P.t += t_ref -P['mean_t']



if twiss_match:
   P.twiss_match(plane='y',beta=tao.lat_list("YAG03",'ele.a.beta'),alpha=tao.lat_list("YAG03",'ele.a.alpha'),inplace=True) 
   P.twiss_match(plane='x',beta=tao.lat_list("YAG03",'ele.b.beta'),alpha=tao.lat_list("YAG03",'ele.b.alpha'),inplace=True)

# Write the file that Tao will read
P.write(PFILE)

# %% [markdown]
# # Check particles

# %%
P.plot('x', 'xp')

# %%
P.twiss('xy')
# Out:
# {'alpha_x': -4.800000002310883,
#  'beta_x': 17.20000000171702,
#  'gamma_x': 1.397674419754921,
#  'emit_x': 3.3698861333763624e-09,
#  'eta_x': -8.119903137781223e-06,
#  'etap_x': -1.5727061299569443e-06,
#  'norm_emit_x': 4.2115695167519294e-07,
#  'alpha_y': -4.800000011596326,
#  'beta_y': 17.200000048258733,
#  'gamma_y': 1.397674421155508,
#  'emit_y': 3.3797998265326207e-09,
#  'eta_y': 1.5067735161993908e-05,
#  'etap_y': 6.056229864526008e-06,
#  'norm_emit_y': 4.223959314579756e-07}

# %% [markdown]
# # # Set initial beam

# %%
tao.cmd('set global plot_on = F')
tao.cmd('set global lattice_calc_on = F')
tao.cmd(f'set beam_init position_file = {PFILE}')
tao.cmd(f'set beam_init track_start = {TRACK_START}')
tao.cmd(f'set beam_init track_end = {TRACK_END}')
tao.cmd(f'set beam_init bunch_charge = {P.charge}')
tao.cmd(f'set beam_init n_particle = {len(P)}')
tao.cmd('set global lattice_calc_on = T')
tao.cmd('set global plot_on = T')


#tao.cmd('call $LCLS_LATTICE/bmad/models/cu_hxr/scripts/Activate_CSR.tao')
#tao.cmd('csron')
# Out:
# []

# %% [markdown]
# # Track

# %%
# Toggle beam
#tao.cmd('set global track_type = beam;set global track_type = single') 
tao.cmd('set global track_type = beam') # default mode is "single"
# Out:
# ['Beam at Element: 413. Time: 1 min',
#  'Beam at Element: 672. Time: 2 min',
#  'Beam at Element: 940. Time: 3 min',
#  'Beam at Element: 1211. Time: 4 min',
#  'Beam at Element: 1516. Time: 5 min']

# %% [markdown]
# # Get partices at end

# %%
P1 = ParticleGroup(data=tao.bunch_data('ENDCLTH_0'))

# %%
P1.plot('x', 'xp')

# %%
slice_plot(P1, 'norm_emit_x', slice_key='t')

# %%
density_and_slice_plot(P1, 't', 'energy', stat_keys = ['norm_emit_x', 'norm_emit_y'], n_slice = 100, bins=100)
#plt.xlim(4.2, 4.3)

# %% [markdown]
# ## Plot

# %%
# %%tao
# x-a all s
# sc
# Out:
# -------------------------
# Tao> x-a all s
# -------------------------
# Tao> sc
# -------------------------
# Tao>

# %% [markdown]
# # Save the files

# %%
PFILE02 = './linac/Tao_output.h5'
P1.write(PFILE02)

# %% [markdown]
# # Genesis Simulations

# %%
from genesis.version4 import Genesis4
from genesis import tools

# %% [markdown]
# ### Read in an match the beam

# %%
PFILE0 = './linac/Tao_output.h5'
P1 = ParticleGroup(PFILE0)
NSAMPLE = len(P1)
P1 = P1.resample(NSAMPLE)

twiss_match = True
alpha_x0 = -0.7393217413918415 
beta_x0 = 7.910909406464387
alpha_y0 = 1.3870723536888105 
beta_y0 = 16.8811786213468987

# Change to s-coordinates (different times t, constant z)
P1.drift_to_z() # drift to P['mean_z']

#t_ref=0
# Zero out the mean time
#P1.t += t_ref -P1['mean_t']

if twiss_match:
    P1.twiss_match(beta =  beta_x0  , alpha =alpha_x0, plane = 'x', inplace = True)
    P1.twiss_match(beta =  beta_y0  , alpha =alpha_y0, plane = 'y', inplace = True)

# %%
P.plot('x', 'xp') #Lets check we have the right beam

# %% [markdown]
# ## Set up the simulation using the lcls repo files

# %%
# Get the relevant files and directories
run_file_location=os.path.expandvars('$LCLS_LATTICE/genesis/version4/cu_hxr/')
run_file=os.path.expandvars('cu_hxr.in')
workdir=os.path.expandvars('$SCRATCH')

G = Genesis4(run_file_location + run_file, workdir=workdir, verbose = True)
# Out:
# Configured to run in: /sdf/scratch/users/j/jmorgan/tmptod18yks

# %%
nproc=16
G.nproc = nproc
# here we can make changes to the input files for this simulatin run in scratch
gamma=15750.807133238239 
lamda0=2.041420496336648e-10
G.input['main'][0]['gamma0'] = gamma # if we need to change gamma0
G.input['main'][0]['lambda0']= lamda0 # lamda needs to change is gamma undulator strength in lat file au=:1.7017

G.input['main'].append({'type': 'write', 'beam': 'end'})  # this writes out the particles at the ened of the simulation

# Now use the partilce data, this will right the particles in the file format the Genesis expects. 
G.initial_particles = P1

G.write_input(path=G.path, input_filename=run_file)
# Out:
# Initial particles written to /sdf/scratch/users/j/jmorgan/tmptod18yks/genesis4_importdistribution.h5
# Updated slen = 3.170168032836144e-05
# Updated existing importdistribution

# %%
# we are ready to run genesis
G.write_input(path=G.path, input_filename=run_file)
runscript = "salloc --partition milano --account ad:beamphysics --mem-per-cpu=4g  -n {nproc} mpirun -n {nproc} {command_mpi} {inputfile}".format(nproc = G.nproc, command_mpi = G.command_mpi, inputfile = G.path + '/' + run_file)
log = []
for path in tools.execute(runscript.split(), cwd=G.path):
    G.vprint(path, end="")
    log.append(path)
G.vprint("Finished.")
# Out:
# Initial particles written to /sdf/scratch/users/j/jmorgan/tmptod18yks/genesis4_importdistribution.h5
# Updated slen = 3.170168032836144e-05
# Updated existing importdistribution
# salloc: Pending job allocation 44737325
# salloc: job 44737325 queued and waiting for resources
# salloc: job 44737325 has been allocated resources
# salloc: Granted job allocation 44737325
# salloc: Waiting for resource configuration
# salloc: Nodes sdfmilan201 are ready for job
# ---------------------------------------------
# GENESIS - Version 4.6.6 has started...
# Compile info: Compiled by conda at 2024-01-11 18:02:26 [UTC] from Git Commit ID: 226c27d5b1b045a8195218d2ce5d63aaa10537c7
# Starting Time: Mon Apr 22 12:29:00 2024
#
# MPI-Comm Size: 16 nodes
#
# Opened input file /sdf/scratch/users/j/jmorgan/tmptod18yks/cu_hxr.in
# Parsing lattice file hxr.lat ...
# Setting up time window of 32.0095 microns with 784 sample points...
# Generating input radiation field for HARM = 1 ...
# Adding profile with label: beamcurrent
# Adding profile with label: beamgamma
# Importing distribution file...
# Charge of external distribution: 2.5e-10
# Particles in external distribution: 300000
# *** Non-matching PArticle Transfar: Rank: 1 Deleted: 16668 Forward: 14052 Backward: 3275
# *** Non-matching PArticle Transfar: Rank: 2 Deleted: 17243 Forward: 12773 Backward: 4891
# *** Non-matching PArticle Transfar: Rank: 3 Deleted: 17533 Forward: 11676 Backward: 6187
# *** Non-matching PArticle Transfar: Rank: 4 Deleted: 17621 Forward: 10679 Backward: 7274
# *** Non-matching PArticle Transfar: Rank: 5 Deleted: 17690 Forward: 9758 Backward: 8224
# *** Non-matching PArticle Transfar: Rank: 6 Deleted: 17737 Forward: 8916 Backward: 9098
# *** Non-matching PArticle Transfar: Rank: 7 Deleted: 17745 Forward: 8038 Backward: 9991
# *** Non-matching PArticle Transfar: Rank: 8 Deleted: 17782 Forward: 7040 Backward: 11013
# *** Non-matching PArticle Transfar: Rank: 9 Deleted: 17742 Forward: 6293 Backward: 11718
# *** Non-matching PArticle Transfar: Rank: 10 Deleted: 17781 Forward: 5447 Backward: 12576
# *** Non-matching PArticle Transfar: Rank: 11 Deleted: 17832 Forward: 4625 Backward: 13473
# *** Non-matching PArticle Transfar: Rank: 12 Deleted: 17747 Forward: 3606 Backward: 14405
# *** Non-matching PArticle Transfar: Rank: 13 Deleted: 17737 Forward: 2837 Backward: 15178
# *** Non-matching PArticle Transfar: Rank: 14 Deleted: 17382 Forward: 1731 Backward: 16068
# *** Non-matching PArticle Transfar: Rank: 15 Deleted: 17071 Forward: 0 Backward: 17326
# Analysing external distribution...
# Analysis of the imported distribution
#    Total Bunch Length  (microns): 31.7017
#    Length for Matching (microns): 31.7017
#    Energy                  (MeV): 8048.65
#    Norm. Emittance in x (micron): 0.575333
#    Norm. Emittance in y (micron): 0.522367
#    Beta Function in x        (m): 7.913
#    Beta Function in y        (m): 16.8635
#    Alpha Function in x          : -0.738192
#    Alpha Function in y          : 1.38449
#    Beam center in x     (micron): -12.2624
#    Beam center in y     (micron): 0.000130292
#    Beam center in px            : -1.02607e-06
#    Beam center in py            : 2.28504e-10
# Sorting external distribution...
# Global Sorting: Slicelength: 0 - Send backwards for theta < 1.58508e-07 - Send forward for theta > 1.80126e-06
# *** Non-matching PArticle Transfar: Rank: 0 Deleted: 15629 Forward: 16000 Backward: 0
# Sorting: Transferring 284168 particles to other nodes at iteration 1 (largest single transfer contains 17326 particles)
# Sorting: Transferring 236713 particles to other nodes at iteration 2 (largest single transfer contains 30296 particles)
# Sorting: Transferring 181069 particles to other nodes at iteration 3 (largest single transfer contains 26931 particles)
# Sorting: Transferring 132520 particles to other nodes at iteration 4 (largest single transfer contains 23559 particles)
# Sorting: Transferring 91329 particles to other nodes at iteration 5 (largest single transfer contains 20113 particles)
# Sorting: Transferring 56853 particles to other nodes at iteration 6 (largest single transfer contains 16422 particles)
# Sorting: Transferring 29641 particles to other nodes at iteration 7 (largest single transfer contains 12382 particles)
# Sorting: Transferring 9843 particles to other nodes at iteration 8 (largest single transfer contains 6400 particles)
# Sorting: Transferring 6 particles to other nodes at iteration 9 (largest single transfer contains 6 particles)
# Sorting: Transferring 6 particles to other nodes at iteration 10 (largest single transfer contains 6 particles)
# Sorting: Transferring 6 particles to other nodes at iteration 11 (largest single transfer contains 6 particles)
# Sorting: Transferring 6 particles to other nodes at iteration 12 (largest single transfer contains 6 particles)
# Sorting: Transferring 6 particles to other nodes at iteration 13 (largest single transfer contains 6 particles)
# Sorting: Transferring 6 particles to other nodes at iteration 14 (largest single transfer contains 6 particles)
# Sorting: Transferring 6 particles to other nodes at iteration 15 (largest single transfer contains 6 particles)
# Info: globalSort complete, largest transfer was 193110 doubles
# Generating internal particle distribution...
#
# Running Core Simulation...
# Time-dependent run with 784 slices for a time window of 32.0095 microns
# Initial analysis of electron beam and radiation field...
#   Calculation: 0% done
#   Calculation: 10% done
#   Calculation: 20% done
#   Calculation: 30% done
#   Calculation: 40% done
#   Calculation: 50% done
#   Calculation: 60% done
#   Calculation: 70% done
#   Calculation: 80% done
#   Calculation: 90% done
# Calculation terminated due to requested stop.
# Writing output file...
#
# Core Simulation done.
# End of Track
# Writing particle distribution to file: end.par.h5 ...
# Writing particle distribution to file: end.par.h5 ...
#
# Program is terminating...
# Ending Time: Mon Apr 22 12:31:16 2024
# Total Wall Clock Time: 134.954 seconds
# -------------------------------------
# Finished.
# salloc: Relinquishing job allocation 44737325
# salloc: Job allocation 44737325 has been revoked.

# %%
G.log = log
G.load_output()
G.plot('field_energy', yscale='log', y2 = ['field_xsize', 'field_ysize'], ylim2=(0e-6, 150e-6))
# Out:
# Loading main output: /sdf/scratch/users/j/jmorgan/tmptod18yks/LCLS2_HXR_9keV.out.h5

# %%
G.load_particles()
P1 = G.particles['end']
P1.drift_to_z()
P1.plot('t', 'energy')
P1
# Out:
# Loaded particle data: 'end' as a ParticleGroup with 799744 particles
# <ParticleGroup with 799744 particles at 0x7f95df314fd0>
